# %%
#importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing plotly library
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True)#Turning on notebook mode
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
#importing the dataset
df =pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
df.head()
# Out:
# C:\Users\chavsan01\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning:
#
# Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
#  11  Cross Street 1                  251419 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2164
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          5914
# Location Type                        131
# Incident Zip                        2615
# Incident Address                   44410
# Street Name                        44410
# Cross Street 1                     49279
# Cross Street 2                     49779
# Intersection Street 1             256840
# Intersection Street 2             257336
# Address Type                        2815
# City                                2614
# Landmark                          300349
# Facility Type                       2171
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2187
# ...

# %%
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.drop(['School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Landmark','Intersection Street 1','Intersection Street 2','School Not Found','School Zip','School Code','School Region','Facility Type'],axis=1,inplace=True)

# %%
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
pd.set_option('display.max_rows',None,'display.max_columns',None)

# %%
df.head(50)
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     32310363  12/31/2015 11:59:45 PM           01-01-16 0:55   NYPD
# 1     32309934  12/31/2015 11:59:44 PM           01-01-16 1:26   NYPD
# 2     32309159  12/31/2015 11:59:29 PM           01-01-16 4:51   NYPD
# 3     32305098  12/31/2015 11:57:46 PM           01-01-16 7:43   NYPD
# 4     32306529  12/31/2015 11:56:58 PM           01-01-16 3:24   NYPD
# 5     32306554  12/31/2015 11:56:30 PM           01-01-16 1:50   NYPD
# 6     32306559  12/31/2015 11:55:32 PM           01-01-16 1:53   NYPD
# 7     32307009  12/31/2015 11:54:05 PM           01-01-16 1:42   NYPD
# 8     32308581  12/31/2015 11:53:58 PM           01-01-16 8:27   NYPD
# 9     32308391  12/31/2015 11:53:58 PM           01-01-16 1:17   NYPD
# 10    32305071  12/31/2015 11:52:58 PM           01-01-16 7:41   NYPD
# 11    32306260  12/31/2015 11:50:57 PM          01-01-16 10:58   NYPD
# ...

# %%
df.nunique()
# Out:
# Unique Key                        300698
# Created Date                      259493
# Closed Date                       237165
# Agency                                 1
# Agency Name                            3
# Complaint Type                        24
# Descriptor                            45
# Location Type                         18
# Incident Zip                         201
# Incident Address                  107652
# Street Name                         7320
# Cross Street 1                      5982
# Cross Street 2                      5823
# Address Type                           5
# City                                  53
# Status                                 4
# Due Date                          259851
# Resolution Description                18
# Resolution Action Updated Date    237895
# Community Board                       75
# Borough                                6
# X Coordinate (State Plane)         63226
# Y Coordinate (State Plane)         73694
# ...

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'])
df['Closed Date'] = pd.to_datetime(df['Closed Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  datetime64[ns]
#  2   Closed Date                     298534 non-null  datetime64[ns]
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
# ...

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
df['Request_Closing_Time']= (df['Closed Date'] - df['Created Date']).dt.total_seconds() / 60.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  datetime64[ns]
#  2   Closed Date                     298534 non-null  datetime64[ns]
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
# ...

# %%
df['Request_Closing_Time_days']= (df['Closed Date'] - df['Created Date']).dt.days

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
df.nunique()
# Out:
# Unique Key                        300698
# Created Date                      259493
# Closed Date                       237165
# Agency                                 1
# Agency Name                            3
# Complaint Type                        24
# Descriptor                            45
# Location Type                         18
# Incident Zip                         201
# Incident Address                  107652
# Street Name                         7320
# Cross Street 1                      5982
# Cross Street 2                      5823
# Address Type                           5
# City                                  53
# Status                                 4
# Due Date                          259851
# Resolution Description                18
# Resolution Action Updated Date    237895
# Community Board                       75
# Borough                                6
# X Coordinate (State Plane)         63226
# Y Coordinate (State Plane)         73694
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(how='any',inplace= True)

# %%
df.isnull().sum()
# Out:
# Unique Key                        0
# Created Date                      0
# Closed Date                       0
# Agency                            0
# Agency Name                       0
# Complaint Type                    0
# Descriptor                        0
# Location Type                     0
# Incident Zip                      0
# Incident Address                  0
# Street Name                       0
# Cross Street 1                    0
# Cross Street 2                    0
# Address Type                      0
# City                              0
# Status                            0
# Due Date                          0
# Resolution Description            0
# Resolution Action Updated Date    0
# Community Board                   0
# Borough                           0
# X Coordinate (State Plane)        0
# Y Coordinate (State Plane)        0
# Park Facility Name                0
# Park Borough                      0
# School Name                       0
# ...

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df['Request_Closing_Time']= df['Request_Closing_Time'].astype(int)

# %%
df['Complaint Type'].value_counts().iplot(kind='bar')
# Out:
# <div>                            <div id="4cf0c63c-723c-4e8b-aa1f-c87ae6840da4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Top 3 Complaint types are Blocked Driveway, Illegal Parking & Noise-Street/Sidewalk

# %%
df['City'].unique()
# Out:
# array(['NEW YORK', 'ASTORIA', 'BRONX', 'ELMHURST', 'BROOKLYN',
#        'KEW GARDENS', 'JACKSON HEIGHTS', 'MIDDLE VILLAGE', 'REGO PARK',
#        'SAINT ALBANS', 'JAMAICA', 'SOUTH RICHMOND HILL', 'RIDGEWOOD',
#        'HOWARD BEACH', 'STATEN ISLAND', 'OZONE PARK', 'FOREST HILLS',
#        'RICHMOND HILL', 'WOODHAVEN', 'FLUSHING', 'CORONA',
#        'QUEENS VILLAGE', 'OAKLAND GARDENS', 'HOLLIS', 'EAST ELMHURST',
#        'SOUTH OZONE PARK', 'WOODSIDE', 'FRESH MEADOWS', 'ROCKAWAY PARK',
#        'SPRINGFIELD GARDENS', 'MASPETH', 'BAYSIDE', 'LONG ISLAND CITY',
#        'GLEN OAKS', 'FAR ROCKAWAY', 'COLLEGE POINT', 'BELLEROSE',
#        'LITTLE NECK', 'CAMBRIA HEIGHTS', 'ROSEDALE', 'SUNNYSIDE',
#        'WHITESTONE', 'ARVERNE', 'FLORAL PARK', 'NEW HYDE PARK',
#        'BREEZY POINT', 'Astoria', 'Long Island City', 'Woodside',
#        'East Elmhurst', 'Howard Beach'], dtype=object)

# %%
#Which City has recorded maximum complaints
df.City.value_counts().head(30).iplot(kind='bar')
# Out:
# <div>                            <div id="369bd404-7168-4b68-9e5c-9e144cd8767a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Brooklyn City has recorded maximum complaints followed by New York & Bronx

# %%
df['Request_Closing_Time'].unique()
# Out:
# array([  55,   86,  291, ..., 3383, 2118, 2303])

# %%
df.sort_values('Request_Closing_Time', ascending= False).head(30)
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 23664     32154771 2015-12-07 18:32:00 2015-12-31 19:53:36   NYPD
# 21268     32167187 2015-12-10 08:25:00 2015-12-31 23:41:01   NYPD
# 12167     32226107 2015-12-18 13:03:23 2015-12-27 20:24:29   NYPD
# 11110     32238859 2015-12-19 15:59:54 2015-12-27 16:36:02   NYPD
# 40690     32034228 2015-11-20 13:35:40 2015-11-27 14:42:28   NYPD
# 27880     32125417 2015-12-03 21:51:00 2015-12-10 02:08:00   NYPD
# 27841     32122269 2015-12-03 22:20:00 2015-12-10 01:47:00   NYPD
# 297534    30312978 2015-04-01 21:18:00 2015-04-08 00:44:00   NYPD
# 297531    30310953 2015-04-01 21:21:00 2015-04-08 00:44:00   NYPD
# 27767     32120343 2015-12-03 23:34:00 2015-12-10 01:48:00   NYPD
# 27720     32126763 2015-12-04 00:19:00 2015-12-10 02:08:00   NYPD
# 39547     32041074 2015-11-21 12:14:18 2015-11-27 10:27:20   NYPD
# 27629     32133544 2015-12-04 04:32:00 2015-12-10 01:48:00   NYPD
# ...

# %% [markdown]
# Ticket Number 32154771 took maximum days (21 days) to get it closed. This ticket was related to Illegal Parking and was reported in Brooklyn City

# %%
df.sort_values('Request_Closing_Time', ascending= True).head(30)
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 61125     31882332 2015-11-01 01:41:00 2015-11-01 01:42:00   NYPD
# 200755    30966965 2015-06-29 19:43:49 2015-06-29 19:46:40   NYPD
# 222119    30823148 2015-06-11 20:39:00 2015-06-11 20:41:00   NYPD
# 100673    31611332 2015-09-25 11:12:55 2015-09-25 11:15:44   NYPD
# 146280    31322840 2015-08-16 22:46:46 2015-08-16 22:49:41   NYPD
# 260083    30581172 2015-05-10 01:33:00 2015-05-10 01:35:00   NYPD
# 45312     31992058 2015-11-15 23:10:49 2015-11-15 23:13:19   NYPD
# 252292    30633896 2015-05-16 21:47:55 2015-05-16 21:50:29   NYPD
# 234706    30739127 2015-05-31 18:56:25 2015-05-31 18:59:12   NYPD
# 42256     32015343 2015-11-18 23:17:34 2015-11-18 23:20:00   NYPD
# 68002     31852609 2015-10-25 11:51:08 2015-10-25 11:53:45   NYPD
# 278833    30460835 2015-04-22 15:27:30 2015-04-22 15:30:13   NYPD
# 107934    31570318 2015-09-19 12:34:32 2015-09-19 12:37:26   NYPD
# ...

# %% [markdown]
# Ticket Number 31882332 took least time (just a min) to get it closed. This ticket was related to Noise-Commercial and was reported in New York City

# %%
df.City.value_counts().sort_values(ascending=True).head(10).iplot(kind='bar')
# Out:
# <div>                            <div id="a0139fc5-5605-4753-a5a1-eb76753b4e7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Howard Beach City has the least complaints recorded

# %%
df['Complaint Type'].unique()
# Out:
# array(['Noise - Street/Sidewalk', 'Blocked Driveway', 'Illegal Parking',
#        'Derelict Vehicle', 'Noise - Commercial',
#        'Noise - House of Worship', 'Posting Advertisement',
#        'Animal Abuse', 'Vending', 'Noise - Vehicle', 'Drinking',
#        'Traffic', 'Noise - Park', 'Graffiti', 'Disorderly Youth'],
#       dtype=object)

# %%
Top_5_Complaint_Type = ['Blocked Driveway','Noise - Street/Sidewalk','Illegal Parking','Derelict Vehicle','Noise - Commercial']

# %%
tdf=df.loc[df['Complaint Type'].isin(Top_5_Complaint_Type)]

# %%
#Comparison between different cities for different complaint types
City_Complaint_Type = pd.crosstab(tdf['City'],tdf['Complaint Type'])
City_Complaint_Type.iplot(kind='bar',barmode='stack')
# Out:
# <div>                            <div id="e404b41e-ced1-43bd-8d32-2f01fc1bd309" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
City_Complaint_Type
# Out:
# Complaint Type       Blocked Driveway  Derelict Vehicle  Illegal Parking  \
# City
# ARVERNE                            35                21               43
# ASTORIA                          2571               279              885
# Astoria                           116                12              213
# BAYSIDE                           371               153              363
# BELLEROSE                          94                61               78
# BREEZY POINT                        3                 3               13
# BRONX                           12538              1607             6256
# BROOKLYN                        27711              4425            23235
# CAMBRIA HEIGHTS                   147                86               45
# COLLEGE POINT                     426               165              304
# CORONA                           2727                48              537
# EAST ELMHURST                    1383                90              725
# ...

# %%
print('Please Provide Ticket Unique Key Number:')
ticket_loc= input('')
def ticket_details(ticket_loc):
    x=df[(df['Unique Key']== ticket_loc)]
    return(x)
ticket_details(ticket_loc)
# Out:
# Please Provide Ticket Unique Key Number:

# %%
df.describe()

# %% [markdown]
# #Average time taken for closing ticket is 260 mins ~ 4hrs
# #Minimum time taken for closing ticket is 1 min
# #Maximum time taken for closing ticket is 34641 mins ~ 24 days
